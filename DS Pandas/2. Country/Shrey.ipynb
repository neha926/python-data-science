# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Countries.csv')

# %%
# which countri has the highest population
df[df['population']==df['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %%
# what is the capital of  country with highest population

# what is the capital of  country with highest population
# df.loc[df['population'].idxmax(),'capital_city']

df[df['population']==df['population'].max()][['capital_city','country']]
# Out:
#    capital_city country
# 75    New Delhi   India

# %%
# what is the capital of  country with least population

df[df['population']==df['population'].min()][['capital_city','country']]
# Out:
#     capital_city country
# 179     Funafuti  Tuvalu

# %%
# what is the capital of  country with least population
# df.loc[df['population'].idxmin(),'capital_city']     #for kown df.sort_values(by='population', ascending=True).head()
# Out:
#     capital_city country
# 179     Funafuti  Tuvalu

# %%
# give me top 5 countries with highest democratic score   for want to knowdf.sort_values(by='democracy_score',ascending=False)
df.sort_values(by='democracy_score',ascending=False).head(5)
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
# how many total regions are there
df['region'].unique()
# Out:
# array(['Southern Asia', 'Southern Europe', 'Northern Africa',
#        'Middle Africa', 'Caribbean', 'South America', 'Western Asia',
#        'Australia and New Zealand', 'Western Europe', 'Eastern Europe',
#        'Central America', 'Western Africa', 'Southern Africa',
#        'South-Eastern Asia', 'Eastern Africa', 'Northern America',
#        'Eastern Asia', 'Northern Europe', 'Melanesia', 'Central Asia',
#        'Micronesia', 'Polynesia'], dtype=object)

# %%
df['region'].value_counts().count()
# Out:
# np.int64(22)

# %%
# how many countries lie in Estern Europe region
# df.loc[df['region']=='Eastern Europe','country'] #konsi

df['region'].value_counts()[['Eastern Europe']]
# Out:
# np.int64(10)

# %%
# Out:
# region
# Eastern Europe    10
# Name: count, dtype: int64

# %%
# who is the political leader of the first highest poluted country
df[df['population']==df['population'].max()][['political_leader','country']]
# Out:
#    political_leader country
# 75    Narendra Modi   India

# %%
df.sort_values(by='population',ascending=False).iloc[1][['political_leader','country']]
# Out:
# political_leader    Xi Jinping
# country                  China
# Name: 34, dtype: object

# %%
# how many countries are there who's leaders are unknown
df[df['political_leader'].isna()]
# Out:
#                             country                        country_long  \
# 27                       Cabo Verde              Republic of Cabo Verde
# 151                 Slovak Republic                     Slovak Republic
# 159             St. Kitts and Nevis                 St. Kitts and Nevis
# 160                       St. Lucia                           St. Lucia
# 161  St. Vincent and the Grenadines      St. Vincent and the Grenadines
# 172                     Timor-Leste  Democratic Republic of Timor-Leste
# 190              West Bank and Gaza                  West Bank and Gaza
#
#                   currency capital_city              region continent  \
# 27       Cabo Verde escudo        Praia      Western Africa    Africa
# 151                   Euro   Bratislava      Eastern Europe    Europe
# 159  East Caribbean dollar   Basseterre           Caribbean  Americas
# 160  East Caribbean dollar     Castries           Caribbean  Americas
# ...

# %%
# how many country have their republic in fullform
df[df['country']==df['country_long']]
# Out:
#                             country                    country_long  \
# 5               Antigua and Barbuda             Antigua and Barbuda
# 13                         Barbados                        Barbados
# 16                           Belize                          Belize
# 20           Bosnia and Herzegovina          Bosnia and Herzegovina
# 25                     Burkina Faso                    Burkina Faso
# 30                           Canada                          Canada
# 31         Central African Republic        Central African Republic
# 43                   Czech Republic                  Czech Republic
# 49               Dominican Republic              Dominican Republic
# 62                          Georgia                         Georgia
# 66                          Grenada                         Grenada
# 73                          Hungary                         Hungary
# 79                          Ireland                         Ireland
# ...

# %%
# how many country have their republic in fullform
df['country_long'].str.lower().str.contains('republic').sum()
# Out:
# np.int64(125)

# %%
# which country in african region has the highest population

# African countries
afdf = df[df['region'].str.contains('Africa')]

# Country with highest population in Africa
afdf[afdf['population'] == afdf['population'].max()][['country', 'population']]
# Out:
#      country  population
# 125  Nigeria   218541212
