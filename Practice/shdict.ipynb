# %%
d={10:100,
   20:200,
   30:300}
sum=0
for i in d:
    sum=sum+d[i]
print(sum)
# Out:
# 600

# %%
l=[3,3,4,2,2,2,1,1,1,1]

print(l.count(1))
d={}
for i in l:
    if i in d.keys():
        d[i]+=1
    else:
        d[i]=1
print(d)
# Out:
# 4
# {3: 2, 4: 1, 2: 3, 1: 4}
