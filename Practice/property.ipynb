# %% [markdown]
# @property =>Getter : gives return value

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks
    @property
    def marks(self):
        return self.__marks

# %%
s=Student(90)
s.marks
# Out:
# 90

# %% [markdown]
# @property =>Getter : gives return value

# %% [markdown]
# @something.setter: To set value and define value

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks

    @property
    def marks(self):
        return self.__marks
    @marks.setter
    def marks(self,value):
        if 0<=value<=100:
            self.__marks=value
        else:
            print("Invalid Marks")

# %%
s=Student(85)

# %%
print(s.marks)
# Out:
# 85

# %%
s.marks=95

# %%
print(s.marks)
# Out:
# 95

# %%
s.marks=150
# Out:
# Invalid Marks

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks

    @property
    def marks(self):
        return self.__marks
        
    @marks.setter
    def marks(self,value):
        if 0<=value<=100:
            self.__marks=value
        else:
            print("Invalid Marks")
        
    @marks.deleter
    def marks(self):
        del self.__marks
        print("Marks deleted")

# %%
s=Student(80)

# %%
print(s.marks)
# Out:
# 80

# %%
del s.marks
# Out:
# Marks deleted

# %%
s.marks=150
# Out:
# Invalid Marks

# %%
print(s.marks)
# Out:
# 90

# %%
del s.marks
# Out:
# Marks deleted

# %%
for i in range(1,11):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
l={i:i**2 for i in range(1,11)}
print(l)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
