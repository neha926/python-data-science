# %%
# i=1 
# while i<=100:
#     print(i)
#     i=i+1



# i=100 
# while i>=1:
#     print(i)
#     i=i-1

# n=int(input("enter no : "))
# for i in range(1,11):
#    print(n*i)

# i=1
# n=4
# while i<=10:
#    print(n*i)
#    i=i+1


# lis=[1,4,9,16,25,36,49,64,81,100]
# for i in lis:
#     print(i)

# lis=[1,4,9,16,25,36,49,64,81,100]
# i=0
# while i<len(lis):
#     print(lis)
#     break



# lis=[1,4,9,16,25,36,49,64,81,100]
# i=0
# while i<len(lis):
#     print(lis[i])
#     i=i+1

# import random
# x=random.randint(1,100)

# i=0
# while True:
#     guess=int(input("enter no : "))
#     if (x==guess):
#         print("found")
#         break
#     else:
#         print("not found",x)
    
    
tup=(16,1,4,9,16,25,36,49,64,81,16,100)
i=0
x=16
while i<len(tup):
    if(tup[i]==x):
        print("found")
    else:
        print("finding....")
    i=i+1
