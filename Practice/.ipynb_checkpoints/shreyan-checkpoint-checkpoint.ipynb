# %%
l=[-1,9,7,-4,2,-6,0]

# %%
for i in l:
    if i<0:
        print(f"{i} negative")
# Out:
# -1 negative
# -4 negative
# -6 negative

# %%
for i in l:
    if i>=0:
        print(f"{i} positive")
# Out:
# 9 positive
# 7 positive
# 2 positive

# %%
l=[12,435,67,89,23,25,69]
sum=0
for i in l:
    sum+=i
print(sum)
print(sum/len(l))
# print(t)
# Out:
# 720
# 102.85714285714286

# %%
l=[4,8,2,9,1,7,10,3,0,33,31,40,39]
large=0
index=0
for i in range(len(l)):
    if large<l[i]:
        large=l[i]
        index=i
print(f"your large no is {large} at index {index}")
# Out:
# your large no is 40 at index 11

# %%
l=[22,43,45,34,44]
large=sec=l[0]

for i in l:
    if i>large:
        sec=large
        large=i
    elif i > sec and i != large:
        sec = i
        
print(f"your large no is {large} and second large {sec}")
# Out:
# your large no is 45 and second large 44

# %%
l=[22,43,45,48]

if l==sorted(l):
    print(f"list is already sorted : {l}")
else:
    l.sort()
    print(l)
# Out:
# list is already sorted : [22, 43, 45, 48]

# %%
l=[11,12,13,14]

for i in range(len(l)-1):
    if l[i]<l[i+1]:
        continue
    else:
        l.sort()
        print(l)
        print("list is sorted")
        break
else:
    print(l)
# Out:
# [11, 12, 13, 14]
