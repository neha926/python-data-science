# %% [markdown]
# <h4>Central Tendancy</h4>

# %% [markdown]
# <h5>Mean</h5>

# %%
import numpy as np 
data=[120,130,110,180,150]
np.mean(data)
# Out:
# np.float64(138.0)

# %% [markdown]
# <h5>affected by outlier</h5>

# %%
data=[1200,130,110,180,150]
np.mean(data)
# Out:
# np.float64(354.0)

# %% [markdown]
# <h5>Median</h5>

# %%
data=[800,130,110,180,150]
np.median(data)
# Out:
# np.float64(150.0)

# %%
data=[800,130,110,180,150]
np.median(data)
# Out:
# np.float64(150.0)

# %% [markdown]
# <h5>Mode</h5>

# %%
import statistics
data=[1,2,6,6,3,4,4]
statistics.mode(data)
# Out:
# 6

# %% [markdown]
# <h4>Practice</h4>

# %%
numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]

# %%
import numpy as np 
import statistics

# %%
np.mean(numbers)
# Out:
# np.float64(19.6)

# %%
np.median(numbers)
# Out:
# np.float64(19.0)

# %%
statistics.mode(numbers)
# Out:
# 12
